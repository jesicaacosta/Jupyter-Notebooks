# %%
import pandas as pd

# Crear un DataFrame con el horario semanal
horario = {
    "Hora": ["6:00 - 6:30", "6:30 - 8:30", "8:30 - 9:00", "9:00 - 10:00", "10:00 - 10:30",
             "10:30 - 12:00", "12:00 - 12:30", "12:30 - 14:30", "14:30 - 15:00", "15:00 - 16:00",
             "16:00 - 16:30", "16:30 - 18:00", "18:00 - 18:30", "18:30 - 20:30", "20:30 - 21:00",
             "21:00 - 22:00", "22:00 - 23:00"],
    "Lunes a Sábado": ["Desayuno", "Matemática (Teoría)", "Pausa activa", "Inglés", "Snack y descanso",
                       "Matemática (Ejercicios)", "Almuerzo", "Geometría (Teoría)", "Descanso activo",
                       "Programación", "Merienda y pausa", "Geometría (Ejercicios)", "Cena ligera",
                       "Seminario", "Repaso ligero", "Tiempo personal", "Relajación y dormir"],
    "Domingo": ["Desayuno", "Repaso general (Mat, Geo, Sem)", "Pausa activa", "Inglés", "Snack y descanso",
                "Repaso general (Ejercicios)", "Almuerzo", "Programación", "Descanso activo",
                "Repaso general o proyecto", "Merienda y pausa", "Repaso general (Ejercicios)", "Cena ligera",
                "Tiempo libre", "Tiempo libre", "Tiempo personal", "Relajación y dormir"]
}

df_horario = pd.DataFrame(horario)

# %%
# Guardar en un archivo Excel
ruta_archivo = "horario_semanal.xlsx"
df_horario.to_excel(ruta_archivo, index=False)

print(f"El horario semanal se ha guardado en '{ruta_archivo}'.")
# Out:
# El horario semanal se ha guardado en 'horario_semanal.xlsx'.

# %%
# Crear un DataFrame con el horario semanal
horario = {
    "Hora": ["6:00 - 6:30", "6:30 - 8:30", "8:30 - 9:00", "9:00 - 10:00", "10:00 - 10:30",
             "10:30 - 12:00", "12:00 - 12:30", "12:30 - 14:30", "14:30 - 15:00", "15:00 - 16:00",
             "16:00 - 16:30", "16:30 - 18:00", "18:00 - 18:30", "18:30 - 20:30", "20:30 - 21:00",
             "21:00 - 22:00", "22:00 - 23:00"],
    "Lunes a Sábado": ["Desayuno", "Matemática (Teoría)", "Pausa activa", "Inglés", "Snack y descanso",
                       "Matemática (Ejercicios)", "Almuerzo", "Geometría (Teoría)", "Descanso activo",
                       "Programación", "Merienda y pausa", "Geometría (Ejercicios)", "Cena ligera",
                       "Seminario", "Repaso ligero", "Tiempo personal", "Relajación y dormir"],
    "Domingo": ["Desayuno", "Repaso general (Mat, Geo, Sem)", "Pausa activa", "Inglés", "Snack y descanso",
                "Repaso general (Ejercicios)", "Almuerzo", "Programación", "Descanso activo",
                "Repaso general o proyecto", "Merienda y pausa", "Repaso general (Ejercicios)", "Cena ligera",
                "Tiempo libre", "Tiempo libre", "Tiempo personal", "Relajación y dormir"]
}

df_horario1 = pd.DataFrame(horario)

# Guardar en un archivo Excel
ruta_archivo1 = "Plan_Estudio_Enero1.xlsx"
df_horario1.to_excel(ruta_archivo1, index=False)

ruta_archivo1
# Out:
# 'Plan_Estudio_Enero1.xlsx'

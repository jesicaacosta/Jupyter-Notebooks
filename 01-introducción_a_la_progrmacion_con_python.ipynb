# %% [markdown]
# # Practica 01 - Introducción a la Progrmación con Python

# %% [markdown]
# ### Variables y operaciones básicas
# ### Ejercicio 1) Hola, mundo
# - Imprime en pantalla el mensaje "Hola, mundo!"

# %% [markdown]
# ### Ejercicio 2) Variables
#
# - Crea dos variables, una para almacenar tu nombre y otra para tu edad.
# - Imprime un mensaje que incluya ambas variables

# %% [markdown]
# ### Ejercico 3) Tipos de datos:
#
# - Crea una variable entera, una de punto flotante y una cadena de caracteres
# - imprime el tipo de cada variable usando la funcion type()

# %% [markdown]
# ### Ejercicio 4) Operaciones básicas:
#
# - Realiza las cuatro operaciones aritméticas básicas (+,-,*,/) entre dos nuúmeros
# - Imprime los resultados

# %% [markdown]
# ### Ejercicio 5) Entrada de datos:
#
# - Pide al ususario que ingrese su nombre y lo almacene en una variable. Para ello utilizar la funcion **input()**
# - Imprime un saludo personalizado.

# %% [markdown]
# ### Ejercicio 5.1) Entrada de datos 2:
#
# - pide al usuario que ingrese un numero
# - imprime ese numero
# - Dile al usuario que tipo de variable es con al funcion type()
#
# NOta: Cuando llegues a este punto notaras que la variable de entrada es una cadena de caracteres (string) y no un numero (int, float, etc)

# %% [markdown]
# ### Ejercicio 5.2) Conversion de datos:
#
# - Pide al usuario que ingrese un número
# - convierte ese numero en un entero con la funcion int()
# - imprime el tipo de variable con la funcion type()
#
# Nota: Aqui podemos observar como con la funsion int podemos decirle a python que lo que hay dentro de la variables es un número y no una cadena de caracteres.

# %% [markdown]
# ### Ejercicio 6) Concatenación de cadenas:
#
# - Concatena dos cadenas para formar una frase

# %% [markdown]
# ### Ejercicio 7) Comentarios:
#
# - Explica que hace cada línea de código utilizando comentarios y ejecuta el código.

# %%
nombre = "Juan"
print(nombre)

# %% [markdown]
# ### Ejercicio 8) Cálculo de promedio de 3 números:
#
# 1) Pide al ususario que ingrese 3 numeros
# 2) Calcula el promedio de los 3 numeros
# 3) Imprime el resultado

# %% [markdown]
# ### Ejercicio 9) Conversión de temperaturas
#
# 1) Pide al usuario que ingrese una temperatura en grados Celsius.
# 2) Convierte la temperatura a grados Fahrenheit utilizando la fórmula: Fahrenheit = (Celsius * 9/5) + 32.
# 3) Imprime el resultado.

# %% [markdown]
# ### Ejercicio 10) Calcular el área de un triángulo
#
# - Pide al usuario que ingrese la base y la altura del triángulo con la funcion **input()**
# - Calcula el área del triángulo y muestra el resultado.
#
# Nota: ärea del triangulo: (base * altura ) / 2

# %% [markdown]
# ### Ejercicio 11) Diferentes formas de escribir en pantalla utilizando la funcion print()
# - Codea el siguiente ejemplo:
#
#         precio = 12.99
#         cantidad = 5
#         total = precio * cantidad
#
#
# -   utiliza la funcion print para mostrar la salida: "El total a pagas es : (total) pesos"
# -  Utiliza los especificadores dentro de la funcion print para escribir en pantalla (%s, %d, %0, %f, etc)
# -  Utiliza F-strings una forma mas concisa y legible de formatear cadenas

# %% [markdown]
# ### Ejercico 12) Continuación escribir en pantalla con la función print()
#
# Existen diferentes especificadores, como ayuda memoria:
# - Especificador  ---------------       Descripción
# -       %s       ---->>     Cadena de caracteres  (Para los enteros el especificador d es implicito que Python lo infiere automaticamente)
#         %d       ---->>     Entero decimal
#         %f       ---->>     Punto flotante
#         %x, %X   ---->>     Entero hexadecimal (minúsculas, mayúsculas)
#         %o       ---->>     Entero octal
#         %e, %E   ---->>     Notación científica (minúsculas, mayúsculas)

# %%
#Especificador d (Entero decimal) como seria el print??
edad = 30

# %%
#Especificador f (punto flotante) el resultado solo conn 2 decimales
pi = 3.14159
radio = 2
area = pi*radio**2

# %%
#Especificador s (Cadena string) Descomentá la linea saludo y allí utiliza el formato f para cadenas (NOTA: puede usarse en variables tambien)
nombre = "Juan"
apellido = "Pérez"
#saludo =
print(saludo)

# %%
#Especificador e oE (Notacion científica)
numero_muy_grande = 1234567890
#inserta el print con notacion cientifica (Ayuda: Para un jumero flotante de dos digitos la forma de escritura es: {variabnle:.2f} piensa como sería con "e"

# %%
#Especificador x o X (Hexadecimal)
numero = 255
#escribe el numero en hexadecimal

# %%
#Especificador o (octal)
numero = 10
#Escribe el numero en octal

# %%
"""
ejemplo completo realiza un print donde combine todas las variables a continuacion
El texto debera decir lo siguiente: Hola Ana. Tienes 25 años y mides 1.65 metros
"""
nombre = "Ana"
edad = 25
altura = 1.65
#Escribe aqui la función print()

# %% [markdown]
# ### Ejercicios EXTRAS - Encuentra y resuleve los errores de los siguientes códigos
#
# - Así mismo en comentarios pon cual es el error encontrado

# %%
print("Hola, mundo"

# %%
numero = input("dime un número y le sumaré 20")
numero_sumado = numero + 20
print("Numero + 20 es: ",numero)

# %%
saludo_IA = "Hola mi nomnbre es IA y estoy aqui para ayudarte"
print(saludos_IA)

# %%
nombre = "Juan
print("Hola", nombre)

# %%
input("¿Cuál es tu nombre?")
print("Su nomnbre es: ", name)

# %%
radio = 5
area = 3.14 * radio
print(Area)

# %%
edad = 15
print("Tengo", edad, "años de edad.")
print("En 5 años tendré", edad + 5, "años.")

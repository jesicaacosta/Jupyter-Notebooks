# %% [markdown]
# # Practica 02 - Estructuras de datos
#
# 1.   Elemento de lista
# 2.   Elemento de lista

# %% [markdown]
# ### Ejercicio 1) Tipos de datos
#
# - Suma dos números del tipo entero

# %% [markdown]
# ### Ejercicio 2)
#
# - Concatena dos variables del tipo str e imprime en pantalla dicha concatenación

# %% [markdown]
# ### Ejercicio 3)
#
# - Multiplica dos números enteros
# - Imprime en pantalla dicho resultado

# %% [markdown]
# ### Ejercicio 4)
#
# - Crea una lista con las variables "manzana" , "banana", "pera" y  "durazno"
# - Imprime dicha lista

# %% [markdown]
# ### Ejercicio 5)
#
# - Crea una lista de 5 números
# - Imprime dicha lista e iomprime su tipo

# %% [markdown]
# ### Ejercicio 6)
#
# - Crea una lista mixta que tenga numeros (enteros y flotantes), palabras y booleanos (True - False)
# - Imprime dicha lista

# %% [markdown]
# ### Ejercicio 7)
#
# - Crea una tupla de 4 números
# - Imprime la tupla e imprime su tipo

# %% [markdown]
# #### Ejercicio 8)
#
# - Crea una tupla con los días de la semana
# - Imprime en pantalla dicha tupla

# %% [markdown]
# ### Ejercicio 9)
#
# - Crea una tupla con la información de una persona que tenga: nombre, edad y ciudad
# - Imprime la tupla

# %% [markdown]
# ### Ejercicio 10)
#
# - Crea un diccionario con los datos de una persona: nombre, edad y ciudad
# - Imprime el diccionario y su tipo

# %% [markdown]
# ### Ejercicio 11)
#
# - Crea el inventario de una verduleria que tenga los siguientes datos: 10 manzanas, 5 bananas y 8 naranjas
# - Imprime el diccionario

# %% [markdown]
# ### Ejercicio 12)
#
# - Configura una aplicacion que tenga los siguientes datos: debug = True, port = 8080, database = mydb
# - Imprime dicha config

# %% [markdown]
# ### Ejercicio 13)
#
# Teniendo en cuenta la siguiente lista abajo presentada:
# - Acceder al segundo elemento e imprimirlo
# - Agregar un elemento al final "comprar pan" utilizando el comando .append
# - Eliminar el primer con el comando .pop
# - Imprimer el resultado de como quedó la lista
# - agrega con la funcion insert en la tercera posición "comprar leche"
# - imprimir lista final

# %%
tareas = ["lavar los platos", "sacar la basura", "estudiar Python", "ir al gimnasio"]

# %% [markdown]
# ### Ejercicio 14)
#
# Dada la siguiente lista de clasificaciones de un alumno:
#
# - Calcular el promedio e imprimirlo en pantalla.
# - Ordenar la lista de mayor a menor e imprimirla en pantalla.

# %%
calificaciones = [9, 8.5, 7, 10, 9, 8]

# %% [markdown]
# ### Ejercicio 15)
#
# Dada la tupla de tuplas:
#
# - guarda en una variable el precio de 5 bananas
# - Imprime en pantalla el precio total de 5 bananas y el nombre del producto sacado de la tupla de tuplas

# %%
productos = (("manzana", 1.5), ("banana", 0.8), ("pera", 1.2))

# %% [markdown]
# ### Ejercicio 16)
#
# De la misma tupla anterior:
#
# - con el comando .pop eliumina el primer elemento de la tupla.
#
# Pregunta: Que pasa al querer eliminar el primer elemento de la tupla??? (La respuesta como comentario)

# %% [markdown]
# ### Ejercicio 17)
#
# Dada la siguiente informacion de un usuario:
#
# - Imprime el segundo hobbie del ususario
# - agrega unanueva clave "correo" = "ana@example.com

# %%
usuario = {
    "nombre": "Ana",
    "edad": 30,
    "ciudad": "Barcelona",
    "hobbies": ["leer", "cocinar", "viajar"]
}

# %% [markdown]
# ### Ejercicio 18)
#
# Dado el siguiente diccionario de listas:
#
# - Accede a la cantidad de naranjas y muestralo en pantalla
# - Accede a la cantidad de tomates y restale 4 e imprime el resultado en pantalla

# %%
inventario = {
    "frutas": {"manzanas": 10, "bananas": 5, "naranjas": 8},
    "verduras": {"lechuga": 20, "tomate": 15}
}

# %% [markdown]
# ## MAnejo de listas continuación
# ### Ejercicio 19) Invertir una lista
#
# - Dada la siguiente lista
# - Invertirla
# - Imprimirla en pantalla

# %%
lista = [1, 2, 3]

# %% [markdown]
# ### Ejercicio 20)
#
# - Dada la lista original:
# - Crear una copia de la lista
# - Agregar un valor al final de la lista
# - Imprimir las dos listas

# %%
original = [1, 2, 3]

# %% [markdown]
# ### Ejercicio 21)
#
# Dada la sigueinte lista:
#
# - Encontrar el indidice del elemento "banana"
# - Imprimir dicho indice

# %%
frutas = ["manzana", "banana", "pera"]

# %% [markdown]
# ### Ejercicio 22)
#
# Dada la siguiente lista
#
# - Contar la cantidad de numeros 2 de la lista
# - Imprimir dicha cantidad

# %%
numeros = [1, 2, 2, 3, 2, 4, 2, 2, 1, 2]

# %% [markdown]
# ### Ejercicio 23)
#
# Dadas las dos listas:
#
# - Unirlas
# - Imprimir la lista unida

# %%
lista1 = [1, 2, 3]
lista2 = [4, 5, 6]

# %% [markdown]
# ### Ejercicio 24) Encuentra el error en el codigo
#
# - Encuentra el error o interpreta el error y escribe el error en un comentario
# - - Copia y pega el codigo en una nueva celda y Modificalo para que se ejecute correctamrente.

# %%
lista = [1, 2, 3]
print(lista[5])

# %%
tupla = (1, 2, 3)
tupla[0] = 4

# %%
diccionario = {"nombre": "Juan", "edad": 30}
print(diccionario["ciudad"])

# %%
nombre = "Juan"
edad = 30
print("Hola, mi nombre es " + nombre + " y tengo " + edad + " años.")

# %%
cadena = "Hola, mundo"
cadena.append("!")

# %%
cadena = "Hola, Mundo"
subcadena = cadena.upper(2)

# %%
cadena = 'El gato dijo 'miau''

# %%
lista = tuple([1,'Hola',3.5])
print(type(lista))
# Out:
# <class 'tuple'>

# %%
lista
# Out:
# (1, 'Hola', 3.5)

# %%
lista[1]
# Out:
# 'Hola'

# %%
#lista[1m_t = ] = 'Chau' #TypeError: 'tuple' object does not support item assignment

# %%
set = {3,5,2,4,3,3,6}
print(type(set))
# Out:
# <class 'set'>

# %%
set
# Out:
# {2, 3, 4, 5, 6}

# %%
set1 = {1,2,3}
set2= {3,4,5}
un = set1.union(set2)
print(un)
# Out:
# {1, 2, 3, 4, 5}

# %%
mi_diccionario = {
'nombre': 'Juan',
'edad': 30,
 'ciudad': 'Madrid'
}

print(mi_diccionario)
# Out:
# {'nombre': 'Juan', 'edad': 30, 'ciudad': 'Madrid'}

# %%
mi_diccionario['nombre']
# Out:
# 'Juan'

# %%
mi_diccionario.keys()
# Out:
# dict_keys(['nombre', 'edad'])

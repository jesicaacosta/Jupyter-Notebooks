# %% [markdown]
# # Practica 03 - Sentencias de control de flujo y funciones

# %% [markdown]
# ### Estructuras de control

# %% [markdown]
# #### Ejercicio 1) Estructura IF
#
# - Escriba un código donde tenga una variable que guarde la edad
# - Con el condicional if escriba el mensaje "Es mayor de edad" si la edad es mayou o igual a 18

# %% [markdown]
# ### Ejercicio 2) Extructura if - else
#
# - Crear un programa que pida al usuario su edad.
# - Utilizar un condicional if-else para determinar si es mayor o menor de edad.
# - Imprimir un mensaje correspondiente.

# %% [markdown]
# ### Ejercicio 3) Estructura if - elif - else
#
# - escriba un codigo donde el input sea la variable nota del  del tipo entero
# - Si la nota esta entre 9 y 10 escriba el mensaje "Excelente"
# - si la nota esta entre 7 y 8 escriba "Notable"
# - si la nota es 6 escriba "mejorable"
# - Si la nota es menor a 6 y mayor a 0 escriba "Puedes mejorar"
# - poara cualquier otro resultado escriba el "número ingressado no esta entre 1 y 10"

# %% [markdown]
# ### Ejercicio 4)
#
# - Solicitar al usuario un número entero.
# - Utilizar el operador módulo (%) para determinar si el número es par o impar.
# - Escribir si el resultado es par o impar

# %% [markdown]
# ### Ejercicio 5) Bucles for
#
# - Dada la lista
# - recorre e imprime item a item toda la lista

# %% [markdown]
# ### Ejercicio 6)
#
# - Utiliza for para imprimir el valor actual de la variable "i" que contiene el valor actual de la iteraccion

# %% [markdown]
# ### Ejercico 7)
#
# - Pedir al usuario un número entero.
# - Utilizar un bucle for para imprimir la tabla de multiplicar de ese número hasta el 10.

# %% [markdown]
# ### Ejercicio 8)
#
# - Pedir al usuario una palabra.
# - Utilizar un bucle for para contar la cantidad de letras de esa palabra.

# %% [markdown]
# ### Ejercicio 9) while
#
# - escribe un codigo que mientras la variable i sea menor o igual a 10 escriba la variable en pantalla

# %% [markdown]
# ### Ejercicio 10)
#
# - Pide al ususario que ingrese un número entero
# - Cuenta los números de 1 en 1 hasta llegar al numero que ingresó el ususario
# - imrpime en pantalla todos los numeros

# %% [markdown]
# ### Ejercicio 11)
#
# - Pide al usuario que ingrese números distintos de "0"
# - Suma los números ingresados por el usuario mientras sean distintos de "0" (cero) y gaurda en una lista cada uno de los números ingresados.
# - si el usuario ingrresa "0" (cero) imprimir el resultado de la suma de todos los numeros ingresados y la lista de numeros ingresados.

# %% [markdown]
# ### Ejercicio 12) While + if-else
#
# - Genera un número aleatorio entre 1 y 100. (Utiliza la función random.randint(1,100) para generar un numero entero aleatorio)
# - Pídele al usuario que adivine el número.
# - Si el número ingresado es mayor, indica que es demasiado alto.
# - Si el número ingresado es menor, indica que es demasiado bajo.
# - Repite el proceso hasta que el usuario adivine el número.
# - Imprime el número y la cantidad de intentos que le llevó adivinarlo
#
# NOTA: PAra poder usar la funcion random.randint() tendrás que importa la libreria random:
#
# import random

# %% [markdown]
# ### Ejercico 13) Funciones
#
# - Crea una función que calcule el factorial de un numero entero positivo

# %% [markdown]
# ### Ejercicio 14)
#
# -Crea una función que determine si un numero es primo

# %% [markdown]
# ### Ejercicio 15)
#
# - Crea una funcion que invierta una cadena

# %% [markdown]
# ### Ejercicio 16) Importacion de modulos
#
# -  Importa el módulo math y utiliza las funciones **sqrt**, **sin**, **cos** y **pi** para calcular la hipotenusa de un triángulo rectángulo, el seno y coseno de un ángulo (en radianes), y el área de un círculo.
#
#
# NOTA: Hypotenusa: raiz cuadrada de la suma de los cuadrados de los catetos
#
# area del circulo: **pi** por radio al cuadrado

# %% [markdown]
# ### Ejercicio 16) Importar solo una funcion de un modulo
#
# - Importa solo la función sqrt del módulo math y utilízala para calcular la raíz cuadrada de un número

# %% [markdown]
# ### Ejercicio 17) Importacion de modulos + funciones
#
# - Importa el modulo random
# - crea una funcion que genere un número aleatorio entre dos valores especificados

# %% [markdown]
# #### Ejercicio 18) Encuentra el error
#
# - REvisa los siguientes códigos e identifica el error.
# - En comentarios escribe cual es el error
# - crea un nuevo coódigo con el error corregido

# %%
import Math

# %%
i = 0
while i < 5:
    print(i)

# %%
x = 6
if x > 5:
print("x es mayor que 5")

# %%
y = 5
if y = 5:
    print("y es igual a 5")

# %%
z = 10

if z > 5:
    print("z es mayor que 5")
else
    print("z es menor o igual a 5")

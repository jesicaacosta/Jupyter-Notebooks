# %% [markdown]
# **INVERT TEXT**

# %%
shopping = ['Agua','Huevos','Aceite','Sal']
nverted_so = list(reversed(shopping))
shopping
# Out:
# ['Agua', 'Huevos', 'Aceite', 'Sal']

# %%
nverted_so
# Out:
# ['Sal', 'Aceite', 'Huevos', 'Agua']

# %% [markdown]
# **INSERT **

# %%
shopping.insert(7,'Jamon')
shopping
# Out:
# ['Agua', 'Huevos', 'Aceite', 'Sal', 'Jamon']

# %%
shopping.insert(1,'Pan')
shopping
# Out:
# ['Agua', 'Pan', 'Huevos', 'Aceite', 'Sal', 'Jamon']

# %% [markdown]
# **COMBINACIÓN Y REPETICIÓN **

# %%
fruit = [ 'Manzana', 'Banana']

# %% [markdown]
# **TUPLAS: SiMiLAR A LISTA STA PRO iNMUTABLE ocupan menos espacio que las lista **

# %%
t = 23, 45,2029, 4873, 464334
t[3]
# Out:
# 4873

# %%
t
# Out:
# (23, 45, 2029, 4873, 464334)

# %%
u = (t), (1,2,3,4,5)
u
# Out:
# ((23, 45, 2029, 4873, 464334), (1, 2, 3, 4, 5))

# %%
type(u)
# Out:
# tuple

# %% [markdown]
# **TUPL CON DOS LSTAS PARAPODER MODIFICAR  ESAS LISTAS**

# %%
# prompt: cream una tupla  con dos listas dentro

mi_tupla = ([1, 2, 3], ['a', 'b', 'c'])
print(mi_tupla)
# Out:
# ([1, 2, 3], ['a', 'b', 'c'])

# %% [markdown]
# TUPLAS VACIAS

# %%
vacío = ()
type(vacío)
# Out:
# tuple

# %%
singleton = 'Hola',
type(singleton)
# Out:
# tuple

# %%
len(singleton)
# Out:
# 1

# %%
si = 'Hola'
type(si)
# Out:
# str

# %% [markdown]
# ** asigno a varables los elementos de una tupla debe ser gual tamaño **

# %%
tu = ('A', 'B', 'C')
le,la,lo = tu
print(le)
print(la)
print(lo)
# Out:
# A
# B
# C

# %%
len(tu)
# Out:
# 3

# %% [markdown]
# DICCNARIOS

# %%
estudiantes = {
    'Juan': {'edad': 20, 'carrera': 'Ingeniería'},
    'Maria': {'edad': 22, 'carrera': 'Medicina'},
    'Pedro': {'edad': 19, 'carrera': 'Arquitectura'}
}

estudiantes
# Out:
# {'Juan': {'edad': 20, 'carrera': 'Ingeniería'},
#  'Maria': {'edad': 22, 'carrera': 'Medicina'},
#  'Pedro': {'edad': 19, 'carrera': 'Arquitectura'}}

# %%
estudiantes['Juan']
# Out:
# {'edad': 20, 'carrera': 'Ingeniería'}

# %%
au = {
    'Nombres': ['Juan', 'Maria', 'Pedro'],
    'Edades': [20, 22, 19],
    'Carreras': ['Ingeniería', 'Medicina', 'Arquitectura']
}

au
# Out:
# {'Nombres': ['Juan', 'Maria', 'Pedro'],
#  'Edades': [20, 22, 19],
#  'Carreras': ['Ingeniería', 'Medicina', 'Arquitectura']}

# %% [markdown]
# CREACON DE DICCIONARIO

# %%
vacío = {}
type(vacío)
# Out:
# dict

# %%
au['Nombres'][1]
# Out:
# 'Maria'

# %% [markdown]
# **AÑADO CLAVE VALOR **

# %%
au['Grado'] = ['Tercero', 'Segundo', 'Cuarto']
au
# Out:
# {'Nombres': ['Juan', 'Maria', 'Pedro'],
#  'Edades': [20, 22, 19],
#  'Carreras': ['Ingeniería', 'Medicina', 'Arquitectura'],
#  'Grado': ['Tercero', 'Segundo', 'Cuarto']}

# %%
print(f'El primer inscripto es: {au["Nombres"][0]}')
# Out:
# El primer inscripto es: Juan

# %% [markdown]
# # ELIMINAR CLAVE VALOR

# %%
del au['Grado']
au
# Out:
# {'Nombres': ['Juan', 'Maria', 'Pedro'],
#  'Edades': [20, 22, 19],
#  'Carreras': ['Ingeniería', 'Medicina', 'Arquitectura']}

# %%
au_copia = au.copy()
au_copia
# Out:
# {'Nombres': ['Juan', 'Maria', 'Pedro'],
#  'Edades': [20, 22, 19],
#  'Carreras': ['Ingeniería', 'Medicina', 'Arquitectura']}

# %%
len(au)
# Out:
# 3

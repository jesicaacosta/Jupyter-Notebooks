# %%
import pandas as pd

# %%
df = pd.read_csv("/content//drive//MyDrive//DATASETS//20231205_info_publica_datos_barrios.csv")
df.head()
# Out:
#    id_renabap nombre_barrio     provincia departamento            localidad  \
# 0           1   Monterrey I  Buenos Aires        Pilar    Presidente Derqui
# 1           2   Malvinas II  Buenos Aires     La Plata  José Melchor Romero
# 2           3   Ferroviario  Buenos Aires     La Plata     Angel Etcheverry
# 3           4   La Favelita  Buenos Aires     La Plata               Tolosa
# 4           5        Casaca  Buenos Aires     La Plata            City Bell
#
#    cantidad_viviendas_aproximadas  cantidad_familias_aproximada  \
# 0                              40                            44
# 1                             290                           319
# 2                             133                           146
# 3                             122                           134
# 4                              20                            22
#
#   decada_de_creacion  anio_de_creacion  \
# 0        Década 1990               NaN
# 1        Década 1990               NaN
# ...

# %%
estadisticas_basicas = df.describe()
estadisticas_basicas
# Out:
#         id_renabap  cantidad_viviendas_aproximadas  \
# count  6467.000000                     6467.000000
# mean   3504.692129                      173.928715
# std    1993.436948                      450.216876
# min       1.000000                        5.000000
# 25%    1778.500000                       30.000000
# 50%    3564.000000                       70.000000
# 75%    5243.500000                      167.000000
# max    6866.000000                    14000.000000
#
#        cantidad_familias_aproximada  anio_de_creacion  superficie_m2
# count                   6467.000000       1688.000000   6.467000e+03
# mean                     191.401732       2014.175355   1.057990e+05
# std                      495.223841          2.956521   2.162298e+05
# min                        6.000000       2010.000000   3.680000e+02
# 25%                       33.000000       2012.000000   1.838500e+04
# 50%                       77.000000       2014.000000   4.644500e+04
# ...

# %%
for column in df.columns:
  print(f"Columna: {column}")
  # acceder a los valores de cada columna usando df[column]
  print(df[column].head())
  print("-" * 20) #separador de codigo
# Out:
# Columna: id_renabap
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# Name: id_renabap, dtype: int64
# --------------------
# Columna: nombre_barrio
# 0    Monterrey I
# 1    Malvinas II
# 2    Ferroviario
# 3    La Favelita
# 4         Casaca
# Name: nombre_barrio, dtype: object
# --------------------
# Columna: provincia
# 0    Buenos Aires
# 1    Buenos Aires
# 2    Buenos Aires
# 3    Buenos Aires
# 4    Buenos Aires
# Name: provincia, dtype: object
# --------------------
# Columna: departamento
# 0       Pilar
# 1    La Plata
# 2    La Plata
# 3    La Plata
# 4    La Plata
# Name: departamento, dtype: object
# --------------------
# Columna: localidad
# 0      Presidente Derqui
# 1    José Melchor Romero
# 2       Angel Etcheverry
# 3                 Tolosa
# 4              City Bell
# Name: localidad, dtype: object
# --------------------
# Columna: cantidad_viviendas_aproximadas
# 0     40
# 1    290
# 2    133
# 3    122
# 4     20
# ...

# %%
def sumar (a,b):
    return a + b
def restar (a,b):
    return a - b
def multiplicar (a,b):
    return a * b
def dividir (a,b):
    return a / b

# %%
import operaciones

mi_suma = operaciones.sumar(2,3)
print(mi_suma)
# Out:
# 5

# %%
from operaciones import restar

mi_resta = restar(5,3)
print(mi_resta)
# Out:
# 2

# %% [markdown]
# ALIAS PARA MODULOS

# %%
import operaciones as ops
mi_suma = ops.sumar(233,322)
print(mi_suma)
# Out:
# 555

# %% [markdown]
# FUNCIONES B

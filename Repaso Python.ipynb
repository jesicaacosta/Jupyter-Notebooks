# %%
def suma (a: int, b: int) -> int :
  """ DocString """
  return a + b

# %%
suma(2933,344)
# Out:
# 3277

# %%
# suma? me devuelve ayuda sobre el objeto

# %%
c = 'codigo'
c
#c?
# Out:
# 'codigo'

# %%
#MANIPULACION DE ARCHIVOS

# %%
def multi (a , b ) -> int :
    """ DocString Permite multiplicar dos enteros
    Args:
    a(int): N1
    b(int): N2

    Returns:
    int: a*b
    """
    return a * b

multi(9, 2)
#res = print ('El resultado es ', multi)
# Out:
# 18

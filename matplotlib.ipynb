# %%
# Matplotlib isualizacion de datos

# %%
import matplotlib.pyplot as plt

# %%
nros = [4,5,4,6] #lista de numeros
nros
# Out:
# [4, 5, 4, 6]

# %%
nros.insert(0, 10)
nros
# Out:
# [10, 4, 5, 4, 6]

# %%
plt.plot(nros)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
